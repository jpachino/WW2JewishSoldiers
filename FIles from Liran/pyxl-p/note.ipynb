# %%
import openpyxl as xl

# %%
wb_path = 'practice.xlsx'
wb = xl.load_workbook(wb_path)

sheet = wb['Sheet1']

sheet.cell(2,1).value
# Out:
# 'a2'

# %%
sheet.cell(2,1).value = 'hello'

wb.save(wb_path)

# %%
for i in range(1,10):
  sheet.cell(i,1).value = i

wb.save(wb_path)
